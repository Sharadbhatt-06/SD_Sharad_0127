# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharadbhatt-06/SD_Sharad_0127/blob/main/type_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
x="a"

# %%
type(x)
# Out:
# str

# %%
x=45
y=15
sum= x+y
mul= x*y
dev= x/y
print(sum)
print(mul)
print(dev)
# Out:
# 60
# 675
# 3.0

# %%
type(sum)
# Out:
# int

# %%
type(dev)
# Out:
# float

# %%
True*True
# Out:
# 1

# %%
n= False
type(n)
# Out:
# bool
