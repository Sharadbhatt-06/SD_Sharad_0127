# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharadbhatt-06/SD_Sharad_0127/blob/main/conditional_statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10
if x>5:
  print("x is geater than 5")
# Out:
# x is geater than 5

# %%
x = 45
if x%2 == 0:
  print("x is even")
else:
  print("x is odd")
# Out:
# x is odd
