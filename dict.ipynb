# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharadbhatt-06/SD_Sharad_0127/blob/main/dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list = [5, 9, 6, 7, 8, 9, 2, 3, 18, 19]

# %%
dict = { "you": "me", "then" : "now", "here": "there" }
dict.keys()
dict.values()
list1 = [dict.keys()]
list2 = [dict.values()]

# %%
list1
list2
# Out:
# [dict_values(['me', 'now', 'there'])]

# %%
list2
# Out:
# [dict_values(['me', 'now', 'there'])]

# %%
dict = { "you": "me", "then" : "now", "here": "there" }
keys = []
value = []
for item in dict.items():
  keys.append(item[0]), value.append(item[1])
  print("keys:", keys)
  print("value:", value)
# Out:
# keys: ['you']
# value: ['me']
# keys: ['you', 'then']
# value: ['me', 'now']
# keys: ['you', 'then', 'here']
# value: ['me', 'now', 'there']
